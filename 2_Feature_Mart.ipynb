# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush-an/INFO7374_Predict_StockPrice/blob/main/2_Feature_Mart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 2: Using the features/factors you take and discovered, e.g., FRED, Fama-French website, ADS, AR, CAPM, momentum factors, volume, price/return lags, etc.) to construct a feature database
# - The target variable Y can be either price or return
# - Frequency could be either daily or monthly

# %% [markdown]
# ## Install Dependency and files

# %%
# %%bash
#
# pip install pandas yfinance ta seaborn matplotlib pandas-datareader jinja2 fredapi openpyxl xgboost scikit-learn statsmodels mlflow ta
#
# if [ ! -f "ads_index_most_current_vintage.xlsx" ]; then
#     wget https://www.philadelphiafed.org/-/media/frbp/assets/surveys-and-data/ads/ads_index_most_current_vintage.xlsx
# fi
# if [ ! -f "F-F_Research_Data_Factors_daily.CSV" ]; then
#   wget https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_daily_CSV.zip
# 	unzip F-F_Research_Data_Factors_daily_CSV.zip
# fi
# Out:
# Requirement already satisfied: pandas in ./.env/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: yfinance in ./.env/lib/python3.9/site-packages (0.2.33)
# Requirement already satisfied: ta in ./.env/lib/python3.9/site-packages (0.11.0)
# Requirement already satisfied: seaborn in ./.env/lib/python3.9/site-packages (0.13.0)
# Requirement already satisfied: matplotlib in ./.env/lib/python3.9/site-packages (3.8.2)
# Requirement already satisfied: pandas-datareader in ./.env/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: fredapi in ./.env/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: openpyxl in ./.env/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: xgboost in ./.env/lib/python3.9/site-packages (2.0.3)
# Requirement already satisfied: scikit-learn in ./.env/lib/python3.9/site-packages (1.3.2)
# Requirement already satisfied: statsmodels in ./.env/lib/python3.9/site-packages (0.14.1)
# Requirement already satisfied: mlflow in ./.env/lib/python3.9/site-packages (2.9.2)
# Requirement already satisfied: pytz>=2020.1 in ./.env/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.env/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./.env/lib/python3.9/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.env/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: html5lib>=1.1 in ./.env/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: appdirs>=1.4.4 in ./.env/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in ./.env/lib/python3.9/site-packages (from yfinance) (2.3.10)
# Requirement already satisfied: multitasking>=0.0.7 in ./.env/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.31 in ./.env/lib/python3.9/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./.env/lib/python3.9/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: peewee>=3.16.2 in ./.env/lib/python3.9/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: lxml>=4.9.1 in ./.env/lib/python3.9/site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: fonttools>=4.22.0 in ./.env/lib/python3.9/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./.env/lib/python3.9/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.env/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.env/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.env/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.env/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.env/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.9/site-packages (from jinja2) (2.1.3)
# Requirement already satisfied: et-xmlfile in ./.env/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: scipy in ./.env/lib/python3.9/site-packages (from xgboost) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.env/lib/python3.9/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in ./.env/lib/python3.9/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: patsy>=0.5.4 in ./.env/lib/python3.9/site-packages (from statsmodels) (0.5.5)
# Requirement already satisfied: cloudpickle<4 in ./.env/lib/python3.9/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: Flask<4 in ./.env/lib/python3.9/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in ./.env/lib/python3.9/site-packages (from mlflow) (0.18.0)
# Requirement already satisfied: gitpython<4,>=2.1.0 in ./.env/lib/python3.9/site-packages (from mlflow) (3.1.40)
# Requirement already satisfied: click<9,>=7.0 in ./.env/lib/python3.9/site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: entrypoints<1 in ./.env/lib/python3.9/site-packages (from mlflow) (0.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.env/lib/python3.9/site-packages (from mlflow) (0.4.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in ./.env/lib/python3.9/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./.env/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in ./.env/lib/python3.9/site-packages (from mlflow) (7.0.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./.env/lib/python3.9/site-packages (from mlflow) (2.0.24)
# Requirement already satisfied: querystring-parser<2 in ./.env/lib/python3.9/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in ./.env/lib/python3.9/site-packages (from mlflow) (14.0.2)
# Requirement already satisfied: gunicorn<22 in ./.env/lib/python3.9/site-packages (from mlflow) (21.2.0)
# Requirement already satisfied: markdown<4,>=3.3 in ./.env/lib/python3.9/site-packages (from mlflow) (3.5.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in ./.env/lib/python3.9/site-packages (from mlflow) (4.25.1)
# Requirement already satisfied: docker<7,>=4.0.0 in ./.env/lib/python3.9/site-packages (from mlflow) (6.1.3)
# Requirement already satisfied: typing-extensions>=4 in ./.env/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (4.9.0)
# Requirement already satisfied: Mako in ./.env/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in ./.env/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.10.0 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: pyjwt>=1.7.0 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.8.0)
# Requirement already satisfied: oauthlib>=3.1.0 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: urllib3<3,>=1.26.7 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.1.0)
# Requirement already satisfied: tabulate>=0.7.7 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.9.0)
# Requirement already satisfied: websocket-client>=0.32.0 in ./.env/lib/python3.9/site-packages (from docker<7,>=4.0.0->mlflow) (1.7.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in ./.env/lib/python3.9/site-packages (from Flask<4->mlflow) (3.0.1)
# Requirement already satisfied: blinker>=1.6.2 in ./.env/lib/python3.9/site-packages (from Flask<4->mlflow) (1.7.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in ./.env/lib/python3.9/site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.env/lib/python3.9/site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.env/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.1)
# Requirement already satisfied: webencodings in ./.env/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in ./.env/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2023.11.17)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/anshumankaran/Documents/GitHub/INFO7374_Predict_StockPrice/.env/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import yfinance as yf
import ta
import getpass
# Out:
# /Users/anshumankaran/Documents/GitHub/INFO7374_Predict_StockPrice/.env/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Define dataset start and end date => Two years worth of data
start_date = datetime(2018, 1, 1)
end_date = datetime(2023, 12, 31)

# Downloaded data
NVDA_STOCK = yf.download("NVDA", start_date, end_date)
NVDA_STOCK.describe()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               Open         High          Low        Close    Adj Close  \
# count  1509.000000  1509.000000  1509.000000  1509.000000  1509.000000
# mean    157.530023   160.415691   154.546222   157.608532   157.330305
# std     122.302656   124.287872   120.093586   122.260984   122.343514
# min      31.622499    32.494999    31.115000    31.770000    31.523224
# 25%      59.950001    60.834999    59.125000    60.049999    59.654922
# 50%     131.365005   133.824997   129.482498   131.477493   131.218185
# 75%     212.000000   217.550003   208.110001   212.580002   212.323410
# max     502.160004   505.480011   494.119995   504.089996   504.045685
#
#              Volume
# count  1.509000e+03
# mean   4.768403e+07
# std    2.149436e+07
# min    9.788400e+06
# 25%    3.368240e+07
# 50%    4.386880e+07
# 75%    5.800080e+07
# max    2.511528e+08

# %%
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-01-02  48.945000  49.875000  48.625000  49.837502  49.312794  35561600
# 2018-01-03  51.025002  53.424999  50.937500  53.117500  52.558266  91470400
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600

# %%
NVDA_STOCK["Returns"] = NVDA_STOCK["Adj Close"] - NVDA_STOCK["Adj Close"].shift(1)
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-02  48.945000  49.875000  48.625000  49.837502  49.312794  35561600
# 2018-01-03  51.025002  53.424999  50.937500  53.117500  52.558266  91470400
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600
#
#              Returns
# Date
# 2018-01-02       NaN
# 2018-01-03  3.245472
# 2018-01-04  0.277039
# 2018-01-05  0.447742
# 2018-01-08  1.632626

# %% [markdown]
# Calculating daily returns:

# %% [markdown]
# Produce the day's difference of the stock dataframe: (`np.log(nvda['Open']) - np.log(nvda['Open'].shift(+1))`)
#
# When we take the logarithm of the ratio between today's closing price and yesterday's, we're essentially computing the daily percentage change in the stock price. Using logarithms in return calculations helps us handle the additive nature of log-returns, making overall return calculations more interpretable and facilitating mathematical operations.

# %%
# Daily return
NVDA_STOCK["Daily_Return"] = np.log(NVDA_STOCK["Adj Close"]) - np.log(NVDA_STOCK["Adj Close"].shift(1))
NVDA_STOCK = NVDA_STOCK.dropna()
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-03  51.025002  53.424999  50.937500  53.117500  52.558266  91470400
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600
# 2018-01-09  55.555000  55.955002  54.660000  55.485001  54.900833  49700000
#
#              Returns  Daily_Return
# Date
# 2018-01-03  3.245472      0.063739
# 2018-01-04  0.277039      0.005257
# 2018-01-05  0.447742      0.008439
# 2018-01-08  1.632626      0.030181
# 2018-01-09 -0.014839     -0.000270

# %% [markdown]
# ### Feature-set 1: Typical Price, Typical_Price_Return
# - `Typical_Price` is the *mean* value of High, Low and Close values

# %%
NVDA_STOCK["Typical_Price"] = NVDA_STOCK[["High", "Low", "Close"]].mean(axis=1)
NVDA_STOCK["Typical_Price_Return"] = (
    np.log(NVDA_STOCK.Typical_Price) - np.log(NVDA_STOCK.Typical_Price.shift(+1))
) * 100.0
NVDA_STOCK = NVDA_STOCK.dropna()
NVDA_STOCK.head()
# Out:
# /var/folders/73/z3xw9gmn0yv1ytg8yv66975w0000gn/T/ipykernel_51602/2203751036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NVDA_STOCK["Typical_Price"] = NVDA_STOCK[["High", "Low", "Close"]].mean(axis=1)
# /var/folders/73/z3xw9gmn0yv1ytg8yv66975w0000gn/T/ipykernel_51602/2203751036.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NVDA_STOCK["Typical_Price_Return"] = (
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600
# 2018-01-09  55.555000  55.955002  54.660000  55.485001  54.900833  49700000
# 2018-01-10  54.549999  55.955002  54.000000  55.919998  55.331249  58266400
#
#              Returns  Daily_Return  Typical_Price  Typical_Price_Return
# Date
# 2018-01-04  0.277039      0.005257      53.694167              2.261820
# 2018-01-05  0.447742      0.008439      53.615833             -0.145995
# 2018-01-08  1.632626      0.030181      55.465000              3.390777
# 2018-01-09 -0.014839     -0.000270      55.366667             -0.177445
# 2018-01-10  0.430416      0.007809      55.291667             -0.135554

# %% [markdown]
# ### Feature-set 2: Common Transforms
# - `log of volume`
# - `pct_change of volume`
# - `difference in volume`
# - `log of 5 day moving average of volume`
# - `Daily volume vs. 200 day moving average`
# - `Daily closing price vs. 50 day exponential moving average`

# %%
NVDA_STOCK["Volume_Log"] = np.log(NVDA_STOCK.Volume)
NVDA_STOCK["Volume_Differencing"] = NVDA_STOCK.Volume.diff()
NVDA_STOCK["Volume_Differencing_10"] = NVDA_STOCK.Volume.diff(10)
NVDA_STOCK["Volumne_Percent_Change"] = NVDA_STOCK.Volume.pct_change()

# %%
# Log of 5 day moving average of volume
NVDA_STOCK["MA_5"] = np.log(NVDA_STOCK.Volume.rolling(5).mean())

# Daily volume vs. 200 day moving average
NVDA_STOCK["Volumne_MA_200"] = (
    NVDA_STOCK.Volume / NVDA_STOCK.Volume.rolling(200).mean() - 1
)

# Daily closing price vs. 50 day Exponential Moving Avg
NVDA_STOCK["Close_EMA_50"] = NVDA_STOCK.Close / NVDA_STOCK.Close.ewm(span=50).mean() - 1

# %%
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600
# 2018-01-09  55.555000  55.955002  54.660000  55.485001  54.900833  49700000
# 2018-01-10  54.549999  55.955002  54.000000  55.919998  55.331249  58266400
#
#              Returns  Daily_Return  Typical_Price  Typical_Price_Return  \
# Date
# 2018-01-04  0.277039      0.005257      53.694167              2.261820
# 2018-01-05  0.447742      0.008439      53.615833             -0.145995
# 2018-01-08  1.632626      0.030181      55.465000              3.390777
# 2018-01-09 -0.014839     -0.000270      55.366667             -0.177445
# 2018-01-10  0.430416      0.007809      55.291667             -0.135554
#
#             Volume_Log  Volume_Differencing  Volume_Differencing_10  \
# Date
# 2018-01-04   17.881572                  NaN                     NaN
# 2018-01-05   17.876167            -314400.0                     NaN
# 2018-01-08   18.294228           30109200.0                     NaN
# 2018-01-09   17.721515          -38421600.0                     NaN
# 2018-01-10   17.880536            8566400.0                     NaN
#
#             Volumne_Percent_Change       MA_5  Volumne_MA_200  Close_EMA_50
# Date
# 2018-01-04                     NaN        NaN             NaN      0.000000
# 2018-01-05               -0.005390        NaN             NaN      0.004134
# 2018-01-08                0.519013        NaN             NaN      0.022527
# 2018-01-09               -0.436007        NaN             NaN      0.016254
# 2018-01-10                0.172362  17.950444             NaN      0.018883

# %% [markdown]
# ### Feature-set 3: Momentum Indicators

# %% [markdown]
# **1. AwesomeOscillatorIndicator**

# %%
NVDA_STOCK['Momentum_AwesomeOscillatorIndicator'] = ta.momentum.AwesomeOscillatorIndicator(NVDA_STOCK.High, NVDA_STOCK.Low,window1 = 5,window2 = 34, fillna=False).awesome_oscillator()

# %% [markdown]
# **2. Kaufman’s Adaptive Moving Average (KAMA)**

# %%
NVDA_STOCK['Momentum_KAMA'] = ta.momentum.KAMAIndicator(NVDA_STOCK.Close, fillna=False).kama()

# %% [markdown]
# **3. PercentagePriceOscillator**

# %%
NVDA_STOCK['Momentum_PercentagePVolumneOscillator'] = ta.momentum.PercentageVolumeOscillator(NVDA_STOCK.Volume, fillna=False).pvo()

# %% [markdown]
# **4. Rate of Change (ROC)**

# %%
NVDA_STOCK['Momentum_ROC'] = ta.momentum.ROCIndicator(NVDA_STOCK.Close, fillna=False).roc()

# %% [markdown]
# **5. Relative Strength Index (RSI)**

# %%
NVDA_STOCK['Momentum_RSI'] = ta.momentum.RSIIndicator(NVDA_STOCK.Close, fillna=False).rsi()

# %% [markdown]
# **6. Stochastic RSI**

# %%
NVDA_STOCK['Momentum_StochRSIIndicator'] = ta.momentum.StochRSIIndicator(NVDA_STOCK.Close, fillna=False).stochrsi()

# %% [markdown]
# **7. True strength index (TSI)**

# %%
NVDA_STOCK['Momentum_TSIIndicator'] = ta.momentum.TSIIndicator(NVDA_STOCK.Close, fillna=False).tsi()

# %%
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600
# 2018-01-09  55.555000  55.955002  54.660000  55.485001  54.900833  49700000
# 2018-01-10  54.549999  55.955002  54.000000  55.919998  55.331249  58266400
#
#              Returns  Daily_Return  Typical_Price  Typical_Price_Return  ...  \
# Date                                                                     ...
# 2018-01-04  0.277039      0.005257      53.694167              2.261820  ...
# 2018-01-05  0.447742      0.008439      53.615833             -0.145995  ...
# 2018-01-08  1.632626      0.030181      55.465000              3.390777  ...
# 2018-01-09 -0.014839     -0.000270      55.366667             -0.177445  ...
# 2018-01-10  0.430416      0.007809      55.291667             -0.135554  ...
#
#                  MA_5  Volumne_MA_200  Close_EMA_50  \
# Date
# 2018-01-04        NaN             NaN      0.000000
# 2018-01-05        NaN             NaN      0.004134
# 2018-01-08        NaN             NaN      0.022527
# 2018-01-09        NaN             NaN      0.016254
# 2018-01-10  17.950444             NaN      0.018883
#
#             Momentum_AwesomeOscillatorIndicator  Momentum_KAMA  \
# Date
# 2018-01-04                                  NaN            NaN
# 2018-01-05                                  NaN            NaN
# 2018-01-08                                  NaN            NaN
# 2018-01-09                                  NaN            NaN
# 2018-01-10                                  NaN            NaN
#
#             Momentum_PercentagePVolumneOscillator  Momentum_ROC  Momentum_RSI  \
# Date
# 2018-01-04                                    NaN           NaN           NaN
# 2018-01-05                                    NaN           NaN           NaN
# 2018-01-08                                    NaN           NaN           NaN
# 2018-01-09                                    NaN           NaN           NaN
# 2018-01-10                                    NaN           NaN           NaN
#
#             Momentum_StochRSIIndicator  Momentum_TSIIndicator
# Date
# 2018-01-04                         NaN                    NaN
# 2018-01-05                         NaN                    NaN
# 2018-01-08                         NaN                    NaN
# 2018-01-09                         NaN                    NaN
# 2018-01-10                         NaN                    NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Feature-set 4: Trend Indicators

# %% [markdown]
# **1. Average Directional Movement Index (ADX)**

# %%
NVDA_STOCK['Trend_ADX'] = ta.trend.ADXIndicator(NVDA_STOCK.High,NVDA_STOCK.Low, NVDA_STOCK.Close, window = 20,fillna=False).adx()

# %% [markdown]
# **2. Aroon Indicator**

# %%
NVDA_STOCK['Trend_AroonIndicator'] = ta.trend.AroonIndicator(NVDA_STOCK.Close, NVDA_STOCK.Low, window=20, fillna=False).aroon_indicator()

# %% [markdown]
# **3. Commodity Channel Index (CCI)**

# %%
NVDA_STOCK['Trend_CCI'] = ta.trend.CCIIndicator(NVDA_STOCK.High, NVDA_STOCK.Low, NVDA_STOCK.Close, window = 20,fillna=False).cci()

# %% [markdown]
# **4. Detrended Price Oscillator (DPO)**

# %%
NVDA_STOCK['Trend_DPO'] = ta.trend.DPOIndicator(NVDA_STOCK.Close, window = 20, fillna=False).dpo()

# %% [markdown]
# **5. EMA - Exponential Moving Average**

# %%
NVDA_STOCK['Trend_EMA'] = ta.trend.EMAIndicator(NVDA_STOCK.Close, window = 20, fillna=False).ema_indicator()

# %% [markdown]
# **6. Moving Average Convergence Divergence (MACD)**

# %%
NVDA_STOCK['Trend_MACD'] = ta.trend.MACD(NVDA_STOCK.Close, fillna=False).macd()

# %% [markdown]
# **7. Mass Index (MI)**

# %%
NVDA_STOCK['Trend_MI'] = ta.trend.MassIndex(NVDA_STOCK.High, NVDA_STOCK.Low, fillna=False).mass_index()

# %%
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600
# 2018-01-09  55.555000  55.955002  54.660000  55.485001  54.900833  49700000
# 2018-01-10  54.549999  55.955002  54.000000  55.919998  55.331249  58266400
#
#              Returns  Daily_Return  Typical_Price  Typical_Price_Return  ...  \
# Date                                                                     ...
# 2018-01-04  0.277039      0.005257      53.694167              2.261820  ...
# 2018-01-05  0.447742      0.008439      53.615833             -0.145995  ...
# 2018-01-08  1.632626      0.030181      55.465000              3.390777  ...
# 2018-01-09 -0.014839     -0.000270      55.366667             -0.177445  ...
# 2018-01-10  0.430416      0.007809      55.291667             -0.135554  ...
#
#             Momentum_RSI  Momentum_StochRSIIndicator  Momentum_TSIIndicator  \
# Date
# 2018-01-04           NaN                         NaN                    NaN
# 2018-01-05           NaN                         NaN                    NaN
# 2018-01-08           NaN                         NaN                    NaN
# 2018-01-09           NaN                         NaN                    NaN
# 2018-01-10           NaN                         NaN                    NaN
#
#             Trend_ADX  Trend_AroonIndicator  Trend_CCI  Trend_DPO  Trend_EMA  \
# Date
# 2018-01-04        0.0                   NaN        NaN        NaN        NaN
# 2018-01-05        0.0                   NaN        NaN        NaN        NaN
# 2018-01-08        0.0                   NaN        NaN        NaN        NaN
# 2018-01-09        0.0                   NaN        NaN        NaN        NaN
# 2018-01-10        0.0                   NaN        NaN        NaN        NaN
#
#             Trend_MACD  Trend_MI
# Date
# 2018-01-04         NaN       NaN
# 2018-01-05         NaN       NaN
# 2018-01-08         NaN       NaN
# 2018-01-09         NaN       NaN
# 2018-01-10         NaN       NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Feature-set 5: Volumne Indicator

# %% [markdown]
# **1. Chaikin Money Flow (CMF)**

# %%
NVDA_STOCK['Volumne_CMF'] = ta.volume.ChaikinMoneyFlowIndicator(NVDA_STOCK.High,NVDA_STOCK.Low,NVDA_STOCK.Close, NVDA_STOCK.Volume,window = 20,fillna=False).chaikin_money_flow()

# %% [markdown]
# **2. Ease of movement (EoM, EMV)**

# %%
NVDA_STOCK['Volumne_EOM'] = ta.volume.EaseOfMovementIndicator(NVDA_STOCK.High,NVDA_STOCK.Low, NVDA_STOCK.Volume,window = 20,fillna=False).ease_of_movement()

# %% [markdown]
# **3. Force Index (FI)**

# %%
NVDA_STOCK['Volumne_FI'] = ta.volume.ForceIndexIndicator(NVDA_STOCK.Close, NVDA_STOCK.Volume,window = 20,fillna=False).force_index()

# %% [markdown]
# **4. Money Flow Index (MFI)**

# %%
NVDA_STOCK['Volumne_MFI'] = ta.volume.money_flow_index(NVDA_STOCK.High, NVDA_STOCK.Low, NVDA_STOCK.Close,NVDA_STOCK.Volume, window=20, fillna=False)

# %% [markdown]
# **5. Volume Weighted Average Price (VWAP)**

# %%
NVDA_STOCK['Volumne_VWAP'] = ta.volume.VolumeWeightedAveragePrice(NVDA_STOCK.High, NVDA_STOCK.Low, NVDA_STOCK.Close,NVDA_STOCK.Volume, window=20, fillna=False).volume_weighted_average_price()

# %%
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.835304  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.283047  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.915672  88121600
# 2018-01-09  55.555000  55.955002  54.660000  55.485001  54.900833  49700000
# 2018-01-10  54.549999  55.955002  54.000000  55.919998  55.331249  58266400
#
#              Returns  Daily_Return  Typical_Price  Typical_Price_Return  ...  \
# Date                                                                     ...
# 2018-01-04  0.277039      0.005257      53.694167              2.261820  ...
# 2018-01-05  0.447742      0.008439      53.615833             -0.145995  ...
# 2018-01-08  1.632626      0.030181      55.465000              3.390777  ...
# 2018-01-09 -0.014839     -0.000270      55.366667             -0.177445  ...
# 2018-01-10  0.430416      0.007809      55.291667             -0.135554  ...
#
#             Trend_CCI  Trend_DPO  Trend_EMA  Trend_MACD  Trend_MI  \
# Date
# 2018-01-04        NaN        NaN        NaN         NaN       NaN
# 2018-01-05        NaN        NaN        NaN         NaN       NaN
# 2018-01-08        NaN        NaN        NaN         NaN       NaN
# 2018-01-09        NaN        NaN        NaN         NaN       NaN
# 2018-01-10        NaN        NaN        NaN         NaN       NaN
#
#             Volumne_CMF  Volumne_EOM  Volumne_FI  Volumne_MFI  Volumne_VWAP
# Date
# 2018-01-04          NaN          NaN         NaN          NaN           NaN
# 2018-01-05          NaN    -0.863636         NaN          NaN           NaN
# 2018-01-08          NaN     3.549348         NaN          NaN           NaN
# 2018-01-09          NaN    -0.364788         NaN          NaN           NaN
# 2018-01-10          NaN    -1.107243         NaN          NaN           NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Feature-set 6: Volatility Indicators

# %% [markdown]
# **1. Average True Range (ATR)**

# %%
NVDA_STOCK['Volatility_ATR'] = ta.volatility.AverageTrueRange(NVDA_STOCK.High, NVDA_STOCK.Low, NVDA_STOCK.Close, window=20, fillna=False).average_true_range()

# %% [markdown]
# **2. Bollinger Bands**

# %%
NVDA_STOCK['Volatility_BB'] = ta.volatility.BollingerBands(NVDA_STOCK.Close, window=20, fillna=False).bollinger_wband()

# %% [markdown]
# **3. Donchian Channel**

# %%
NVDA_STOCK['Volatility_DonchainChannel'] = ta.volatility.DonchianChannel(NVDA_STOCK.High, NVDA_STOCK.Low,NVDA_STOCK.Close, window=20, fillna=False).donchian_channel_wband()

# %% [markdown]
# **4. Ulcer Index**

# %%
NVDA_STOCK['Volatility_UlcerIndex'] = ta.volatility.UlcerIndex(NVDA_STOCK.Close, window=20, fillna=False).ulcer_index()

# %% [markdown]
# **5. Keltner channel (KC)**

# %%
NVDA_STOCK['Volatility_KeltnerChannel'] = ta.volatility.keltner_channel_hband(NVDA_STOCK.High, NVDA_STOCK.Low,NVDA_STOCK.Close, window=20, fillna=False)

# %%
NVDA_STOCK.dropna(inplace = True)

# %%
NVDA_STOCK.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-10-18  61.465000  61.852501  59.272499  59.882500  59.357967  52402000
# 2018-10-19  60.439999  60.637501  56.924999  57.292500  56.790657  61360800
# 2018-10-22  57.820000  58.830002  56.767502  57.805000  57.298664  36884400
# 2018-10-23  55.107498  56.047501  54.177502  55.264999  54.780914  62643600
# 2018-10-24  54.877499  55.347500  49.712502  49.852501  49.415825  88428800
#
#              Returns  Daily_Return  Typical_Price  Typical_Price_Return  ...  \
# Date                                                                     ...
# 2018-10-18 -0.874771     -0.014630      60.335833             -1.370346  ...
# 2018-10-19 -2.567310     -0.044215      58.285000             -3.458141  ...
# 2018-10-22  0.508007      0.008905      57.800835             -0.834155  ...
# 2018-10-23 -2.517750     -0.044935      55.163334             -4.670472  ...
# 2018-10-24 -5.365089     -0.103071      51.637501             -6.605032  ...
#
#             Volumne_CMF  Volumne_EOM    Volumne_FI  Volumne_MFI  Volumne_VWAP  \
# Date
# 2018-10-18    -0.166595    -3.975714 -2.515214e+07    45.203574     65.418863
# 2018-10-19    -0.189750   -10.777065 -3.789236e+07    44.660537     64.892034
# 2018-10-22    -0.219260    -5.493928 -3.248325e+07    44.509744     64.570526
# 2018-10-23    -0.216777    -8.018833 -4.454340e+07    40.195354     63.871194
# 2018-10-24    -0.269425   -16.456613 -8.588410e+07    35.541378     62.703614
#
#             Volatility_ATR  Volatility_BB  Volatility_DonchainChannel  \
# Date
# 2018-10-18        2.260525      26.135972                   22.298079
# 2018-10-19        2.333124      28.543358                   24.961590
# 2018-10-22        2.319593      30.310946                   25.371115
# 2018-10-23        2.384988      32.945426                   29.643461
# 2018-10-24        2.547489      38.472874                   37.093141
#
#             Volatility_UlcerIndex  Volatility_KeltnerChannel
# Date
# 2018-10-18              10.741495                  67.986543
# 2018-10-19              11.595971                  67.696292
# 2018-10-22              12.354732                  67.307376
# 2018-10-23              13.380735                  66.757917
# 2018-10-24              15.020365                  66.224375
#
# [5 rows x 41 columns]

# %%
NVDA_STOCK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1308 entries, 2018-10-18 to 2023-12-29
# Data columns (total 41 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Open                                   1308 non-null   float64
#  1   High                                   1308 non-null   float64
#  2   Low                                    1308 non-null   float64
#  3   Close                                  1308 non-null   float64
#  4   Adj Close                              1308 non-null   float64
#  5   Volume                                 1308 non-null   int64
#  6   Returns                                1308 non-null   float64
#  7   Daily_Return                           1308 non-null   float64
#  8   Typical_Price                          1308 non-null   float64
#  9   Typical_Price_Return                   1308 non-null   float64
#  10  Volume_Log                             1308 non-null   float64
#  11  Volume_Differencing                    1308 non-null   float64
#  12  Volume_Differencing_10                 1308 non-null   float64
#  13  Volumne_Percent_Change                 1308 non-null   float64
#  14  MA_5                                   1308 non-null   float64
#  15  Volumne_MA_200                         1308 non-null   float64
#  16  Close_EMA_50                           1308 non-null   float64
#  17  Momentum_AwesomeOscillatorIndicator    1308 non-null   float64
#  18  Momentum_KAMA                          1308 non-null   float64
#  19  Momentum_PercentagePVolumneOscillator  1308 non-null   float64
#  20  Momentum_ROC                           1308 non-null   float64
#  21  Momentum_RSI                           1308 non-null   float64
#  22  Momentum_StochRSIIndicator             1308 non-null   float64
#  23  Momentum_TSIIndicator                  1308 non-null   float64
#  24  Trend_ADX                              1308 non-null   float64
#  25  Trend_AroonIndicator                   1308 non-null   float64
#  26  Trend_CCI                              1308 non-null   float64
#  27  Trend_DPO                              1308 non-null   float64
#  28  Trend_EMA                              1308 non-null   float64
#  29  Trend_MACD                             1308 non-null   float64
#  30  Trend_MI                               1308 non-null   float64
#  31  Volumne_CMF                            1308 non-null   float64
#  32  Volumne_EOM                            1308 non-null   float64
#  33  Volumne_FI                             1308 non-null   float64
#  34  Volumne_MFI                            1308 non-null   float64
#  35  Volumne_VWAP                           1308 non-null   float64
#  36  Volatility_ATR                         1308 non-null   float64
#  37  Volatility_BB                          1308 non-null   float64
#  38  Volatility_DonchainChannel             1308 non-null   float64
#  39  Volatility_UlcerIndex                  1308 non-null   float64
#  40  Volatility_KeltnerChannel              1308 non-null   float64
# dtypes: float64(40), int64(1)
# memory usage: 429.2 KB

# %% [markdown]
# ### Feature-set 7: Fama-French Indicators

# %%
df_fama = pd.read_csv("./F-F_Research_Data_Factors_daily.CSV", skiprows=3)
df_fama = df_fama.iloc[:-1]
df_fama.rename(columns={"Unnamed: 0": "Date"}, inplace=True)
df_fama["Date"] = pd.to_datetime(df_fama["Date"])
df_fama = df_fama[(df_fama["Date"] >= start_date) & (df_fama["Date"] <= end_date)]
fama = df_fama.set_index("Date")

# %%
fama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1489 entries, 2018-01-02 to 2023-11-30
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mkt-RF  1489 non-null   float64
#  1   SMB     1489 non-null   float64
#  2   HML     1489 non-null   float64
#  3   RF      1489 non-null   float64
# dtypes: float64(4)
# memory usage: 58.2 KB

# %%
NVDA_STOCK = pd.concat([NVDA_STOCK, fama], axis=1)
NVDA_STOCK.dropna(inplace=True)
NVDA_STOCK
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-10-18   61.465000   61.852501   59.272499   59.882500   59.357967
# 2018-10-19   60.439999   60.637501   56.924999   57.292500   56.790657
# 2018-10-22   57.820000   58.830002   56.767502   57.805000   57.298664
# 2018-10-23   55.107498   56.047501   54.177502   55.264999   54.780914
# 2018-10-24   54.877499   55.347500   49.712502   49.852501   49.415825
# ...                ...         ...         ...         ...         ...
# 2023-11-24  484.700012  489.209991  477.450012  477.760010  477.718018
# 2023-11-27  478.000000  485.299988  476.519989  482.420013  482.377594
# 2023-11-28  482.359985  483.230011  474.730011  478.209991  478.167938
# 2023-11-29  483.790009  487.619995  478.600006  481.399994  481.357666
# 2023-11-30  480.239990  481.100006  464.220001  467.700012  467.658905
#
#                 Volume    Returns  Daily_Return  Typical_Price  \
# Date
# 2018-10-18  52402000.0  -0.874771     -0.014630      60.335833
# 2018-10-19  61360800.0  -2.567310     -0.044215      58.285000
# 2018-10-22  36884400.0   0.508007      0.008905      57.800835
# 2018-10-23  62643600.0  -2.517750     -0.044935      55.163334
# 2018-10-24  88428800.0  -5.365089     -0.103071      51.637501
# ...                ...        ...           ...            ...
# 2023-11-24  29464500.0  -9.399170     -0.019484     481.473338
# 2023-11-27  39566200.0   4.659576      0.009707     481.413330
# 2023-11-28  40149100.0  -4.209656     -0.008765     478.723338
# 2023-11-29  38200500.0   3.189728      0.006649     482.539998
# 2023-11-30  52624700.0 -13.698761     -0.028871     471.006673
#
#             Typical_Price_Return  ...  Volumne_VWAP  Volatility_ATR  \
# Date                              ...
# 2018-10-18             -1.370346  ...     65.418863        2.260525
# 2018-10-19             -3.458141  ...     64.892034        2.333124
# 2018-10-22             -0.834155  ...     64.570526        2.319593
# 2018-10-23             -4.670472  ...     63.871194        2.384988
# 2018-10-24             -6.605032  ...     62.703614        2.547489
# ...                          ...  ...           ...             ...
# 2023-11-24             -1.579108  ...    464.689991       14.943944
# 2023-11-27             -0.012464  ...    468.258318       14.635746
# 2023-11-28             -0.560337  ...    471.260490       14.328959
# 2023-11-29              0.794097  ...    475.865551       14.083011
# 2023-11-30             -2.419155  ...    478.450966       14.237860
#
#             Volatility_BB  Volatility_DonchainChannel  Volatility_UlcerIndex  \
# Date
# 2018-10-18      26.135972                   22.298079              10.741495
# 2018-10-19      28.543358                   24.961590              11.595971
# 2018-10-22      30.310946                   25.371115              12.354732
# 2018-10-23      32.945426                   29.643461              13.380735
# 2018-10-24      38.472874                   37.093141              15.020365
# ...                   ...                         ...                    ...
# 2023-11-24      27.269391                   24.349504               6.059404
# 2023-11-27      24.524721                   24.148394               5.311905
# 2023-11-28      21.710106                   23.978031               4.684455
# 2023-11-29      17.658367                   20.347052               3.786048
# 2023-11-30      14.538398                   16.015301               3.478111
#
#             Volatility_KeltnerChannel  Mkt-RF   SMB   HML     RF
# Date
# 2018-10-18                  67.986543   -1.54 -0.54  0.42  0.008
# 2018-10-19                  67.696292   -0.25 -1.33  0.71  0.008
# 2018-10-22                  67.307376   -0.38  0.48 -1.25  0.008
# 2018-10-23                  66.757917   -0.62 -0.10 -0.41  0.008
# 2018-10-24                  66.224375   -3.33 -0.93  0.77  0.008
# ...                               ...     ...   ...   ...    ...
# 2023-11-24                 476.756838    0.11  0.59  0.19  0.021
# 2023-11-27                 480.384171   -0.23 -0.11 -0.08  0.021
# 2023-11-28                 483.534838    0.06 -0.29  0.05  0.021
# 2023-11-29                 487.140170    0.01  0.44  0.69  0.021
# 2023-11-30                 489.849337    0.35 -0.45  0.01  0.021
#
# [1288 rows x 45 columns]

# %% [markdown]
# ### Feature-set 8: Exracting external factors using Fred API

# %%
from fredapi import Fred
key = getpass.getpass()
fred = Fred(api_key=key)

# %%
# Japanese Yen to U.S. Dollar Spot Exchange Rate
# U.S. Dollars to Euro Spot Exchange Rate
# Coinbase Bitcoin
feat_list = ["SP500", "DEXJPUS", "DEXUSEU", "CBBTCUSD"]
feat_df = pd.DataFrame()
for feat in feat_list:
    feature = fred.get_series(feat, start_date, end_date)
    feature = feature.to_frame(feat)
    feature.dropna(inplace=True)
    feat_df = pd.concat([feat_df, feature], axis=1)
feat_df.dropna(inplace=True)
feat_df
# Out:
#               SP500  DEXJPUS  DEXUSEU  CBBTCUSD
# 2018-01-02  2695.81   112.18   1.2050  14781.51
# 2018-01-03  2713.06   112.28   1.2030  15098.14
# 2018-01-04  2723.99   112.78   1.2064  15144.99
# 2018-01-05  2743.15   113.18   1.2039  16960.01
# 2018-01-08  2747.71   113.08   1.1973  14993.74
# ...             ...      ...      ...       ...
# 2023-12-22  4754.63   142.60   1.1008  44015.60
# 2023-12-26  4774.75   142.48   1.1035  42520.26
# 2023-12-27  4781.58   142.05   1.1114  43444.45
# 2023-12-28  4783.35   141.08   1.1073  42613.04
# 2023-12-29  4769.83   140.92   1.1062  42056.30
#
# [1489 rows x 4 columns]

# %%
NVDA_STOCK = pd.concat([NVDA_STOCK, feat_df], axis=1)
NVDA_STOCK.dropna(inplace=True)
NVDA_STOCK
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2018-10-18   61.465000   61.852501   59.272499   59.882500   59.357967
# 2018-10-19   60.439999   60.637501   56.924999   57.292500   56.790657
# 2018-10-22   57.820000   58.830002   56.767502   57.805000   57.298664
# 2018-10-23   55.107498   56.047501   54.177502   55.264999   54.780914
# 2018-10-24   54.877499   55.347500   49.712502   49.852501   49.415825
# ...                ...         ...         ...         ...         ...
# 2023-11-24  484.700012  489.209991  477.450012  477.760010  477.718018
# 2023-11-27  478.000000  485.299988  476.519989  482.420013  482.377594
# 2023-11-28  482.359985  483.230011  474.730011  478.209991  478.167938
# 2023-11-29  483.790009  487.619995  478.600006  481.399994  481.357666
# 2023-11-30  480.239990  481.100006  464.220001  467.700012  467.658905
#
#                 Volume    Returns  Daily_Return  Typical_Price  \
# 2018-10-18  52402000.0  -0.874771     -0.014630      60.335833
# 2018-10-19  61360800.0  -2.567310     -0.044215      58.285000
# 2018-10-22  36884400.0   0.508007      0.008905      57.800835
# 2018-10-23  62643600.0  -2.517750     -0.044935      55.163334
# 2018-10-24  88428800.0  -5.365089     -0.103071      51.637501
# ...                ...        ...           ...            ...
# 2023-11-24  29464500.0  -9.399170     -0.019484     481.473338
# 2023-11-27  39566200.0   4.659576      0.009707     481.413330
# 2023-11-28  40149100.0  -4.209656     -0.008765     478.723338
# 2023-11-29  38200500.0   3.189728      0.006649     482.539998
# 2023-11-30  52624700.0 -13.698761     -0.028871     471.006673
#
#             Typical_Price_Return  ...  Volatility_UlcerIndex  \
# 2018-10-18             -1.370346  ...              10.741495
# 2018-10-19             -3.458141  ...              11.595971
# 2018-10-22             -0.834155  ...              12.354732
# 2018-10-23             -4.670472  ...              13.380735
# 2018-10-24             -6.605032  ...              15.020365
# ...                          ...  ...                    ...
# 2023-11-24             -1.579108  ...               6.059404
# 2023-11-27             -0.012464  ...               5.311905
# 2023-11-28             -0.560337  ...               4.684455
# 2023-11-29              0.794097  ...               3.786048
# 2023-11-30             -2.419155  ...               3.478111
#
#             Volatility_KeltnerChannel  Mkt-RF   SMB   HML     RF    SP500  \
# 2018-10-18                  67.986543   -1.54 -0.54  0.42  0.008  2768.78
# 2018-10-19                  67.696292   -0.25 -1.33  0.71  0.008  2767.78
# 2018-10-22                  67.307376   -0.38  0.48 -1.25  0.008  2755.88
# 2018-10-23                  66.757917   -0.62 -0.10 -0.41  0.008  2740.69
# 2018-10-24                  66.224375   -3.33 -0.93  0.77  0.008  2656.10
# ...                               ...     ...   ...   ...    ...      ...
# 2023-11-24                 476.756838    0.11  0.59  0.19  0.021  4559.34
# 2023-11-27                 480.384171   -0.23 -0.11 -0.08  0.021  4550.43
# 2023-11-28                 483.534838    0.06 -0.29  0.05  0.021  4554.89
# 2023-11-29                 487.140170    0.01  0.44  0.69  0.021  4550.58
# 2023-11-30                 489.849337    0.35 -0.45  0.01  0.021  4567.80
#
#             DEXJPUS  DEXUSEU  CBBTCUSD
# 2018-10-18   112.11   1.1494   6394.96
# 2018-10-19   112.52   1.1513   6382.99
# 2018-10-22   112.78   1.1467   6407.65
# 2018-10-23   112.12   1.1480   6395.14
# 2018-10-24   112.58   1.1389   6415.98
# ...             ...      ...       ...
# 2023-11-24   149.57   1.0934  37745.94
# 2023-11-27   148.89   1.0937  37244.39
# 2023-11-28   147.41   1.1007  37840.46
# 2023-11-29   147.39   1.0969  37864.76
# 2023-11-30   147.87   1.0908  37743.00
#
# [1269 rows x 49 columns]

# %% [markdown]
# ### Feature-set 8: ADS features

# %%
ads = pd.read_excel("ads_index_most_current_vintage.xlsx")
ads.rename(columns={"Unnamed: 0": "Date"}, inplace=True)
ads["Date"] = pd.to_datetime(ads["Date"], format="%Y:%m:%d")
ads = ads[(ads["Date"] >= start_date) & (ads["Date"] <= end_date)]
ads = ads.set_index("Date")
ads
# Out:
#             ADS_Index
# Date
# 2018-01-01  -0.261093
# 2018-01-02  -0.284242
# 2018-01-03  -0.305222
# 2018-01-04  -0.324039
# 2018-01-05  -0.340703
# ...               ...
# 2023-12-19  -0.005191
# 2023-12-20  -0.006551
# 2023-12-21  -0.007530
# 2023-12-22  -0.008130
# 2023-12-23  -0.008348
#
# [2183 rows x 1 columns]

# %%
ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2183 entries, 2018-01-01 to 2023-12-23
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ADS_Index  2183 non-null   float64
# dtypes: float64(1)
# memory usage: 34.1 KB

# %%
NVDA_STOCK = pd.concat([NVDA_STOCK, ads], axis=1)
NVDA_STOCK.dropna(inplace=True)
NVDA_STOCK
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2018-10-18   61.465000   61.852501   59.272499   59.882500   59.357967
# 2018-10-19   60.439999   60.637501   56.924999   57.292500   56.790657
# 2018-10-22   57.820000   58.830002   56.767502   57.805000   57.298664
# 2018-10-23   55.107498   56.047501   54.177502   55.264999   54.780914
# 2018-10-24   54.877499   55.347500   49.712502   49.852501   49.415825
# ...                ...         ...         ...         ...         ...
# 2023-11-24  484.700012  489.209991  477.450012  477.760010  477.718018
# 2023-11-27  478.000000  485.299988  476.519989  482.420013  482.377594
# 2023-11-28  482.359985  483.230011  474.730011  478.209991  478.167938
# 2023-11-29  483.790009  487.619995  478.600006  481.399994  481.357666
# 2023-11-30  480.239990  481.100006  464.220001  467.700012  467.658905
#
#                 Volume    Returns  Daily_Return  Typical_Price  \
# 2018-10-18  52402000.0  -0.874771     -0.014630      60.335833
# 2018-10-19  61360800.0  -2.567310     -0.044215      58.285000
# 2018-10-22  36884400.0   0.508007      0.008905      57.800835
# 2018-10-23  62643600.0  -2.517750     -0.044935      55.163334
# 2018-10-24  88428800.0  -5.365089     -0.103071      51.637501
# ...                ...        ...           ...            ...
# 2023-11-24  29464500.0  -9.399170     -0.019484     481.473338
# 2023-11-27  39566200.0   4.659576      0.009707     481.413330
# 2023-11-28  40149100.0  -4.209656     -0.008765     478.723338
# 2023-11-29  38200500.0   3.189728      0.006649     482.539998
# 2023-11-30  52624700.0 -13.698761     -0.028871     471.006673
#
#             Typical_Price_Return  ...  Volatility_KeltnerChannel  Mkt-RF  \
# 2018-10-18             -1.370346  ...                  67.986543   -1.54
# 2018-10-19             -3.458141  ...                  67.696292   -0.25
# 2018-10-22             -0.834155  ...                  67.307376   -0.38
# 2018-10-23             -4.670472  ...                  66.757917   -0.62
# 2018-10-24             -6.605032  ...                  66.224375   -3.33
# ...                          ...  ...                        ...     ...
# 2023-11-24             -1.579108  ...                 476.756838    0.11
# 2023-11-27             -0.012464  ...                 480.384171   -0.23
# 2023-11-28             -0.560337  ...                 483.534838    0.06
# 2023-11-29              0.794097  ...                 487.140170    0.01
# 2023-11-30             -2.419155  ...                 489.849337    0.35
#
#              SMB   HML     RF    SP500  DEXJPUS  DEXUSEU  CBBTCUSD  ADS_Index
# 2018-10-18 -0.54  0.42  0.008  2768.78   112.11   1.1494   6394.96  -0.479897
# 2018-10-19 -1.33  0.71  0.008  2767.78   112.52   1.1513   6382.99  -0.479024
# 2018-10-22  0.48 -1.25  0.008  2755.88   112.78   1.1467   6407.65  -0.471985
# 2018-10-23 -0.10 -0.41  0.008  2740.69   112.12   1.1480   6395.14  -0.468746
# 2018-10-24 -0.93  0.77  0.008  2656.10   112.58   1.1389   6415.98  -0.465132
# ...          ...   ...    ...      ...      ...      ...       ...        ...
# 2023-11-24  0.59  0.19  0.021  4559.34   149.57   1.0934  37745.94  -0.037251
# 2023-11-27 -0.11 -0.08  0.021  4550.43   148.89   1.0937  37244.39  -0.016501
# 2023-11-28 -0.29  0.05  0.021  4554.89   147.41   1.1007  37840.46  -0.010576
# 2023-11-29  0.44  0.69  0.021  4550.58   147.39   1.0969  37864.76  -0.005185
# 2023-11-30 -0.45  0.01  0.021  4567.80   147.87   1.0908  37743.00  -0.000325
#
# [1269 rows x 50 columns]

# %% [markdown]
# Saving the final dataframe as the *feature mart.*

# %%
filename = f"NVDA_feature_mart.csv"
NVDA_STOCK.to_csv(filename, index=True)
