# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush-an/INFO7374_Predict_StockPrice/blob/main/1_NVDA_vs_Competitors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PART 1. Focus on the stock you pick and their competitors
# - Report summary statistics of the training period and plot the kernel density
#
# | Symbol | Company | Year |
# |---|---|---|
# | NVDA | Nvidia Corporation | 1999 |
# | AMD | Advanced Micro Devices (AMD) | 1972 |
# | QCOM | Qualcomm Inc | 1991 |
# | TSM | Taiwan Semiconductor Mfg. Co. Ltd. | 1997 |
# | AVGO | Broadcom Corporation | 1961 |

# %% [markdown]
# ## Install Dependency and files

# %%
# %%bash
#
# pip install pandas yfinance ta seaborn matplotlib pandas-datareader jinja2 fredapi openpyxl xgboost scikit-learn statsmodels mlflow
# Out:
# Requirement already satisfied: pandas in ./.env/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: yfinance in ./.env/lib/python3.9/site-packages (0.2.33)
# Requirement already satisfied: ta in ./.env/lib/python3.9/site-packages (0.11.0)
# Requirement already satisfied: seaborn in ./.env/lib/python3.9/site-packages (0.13.0)
# Requirement already satisfied: matplotlib in ./.env/lib/python3.9/site-packages (3.8.2)
# Requirement already satisfied: pandas-datareader in ./.env/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: fredapi in ./.env/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: openpyxl in ./.env/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: xgboost in ./.env/lib/python3.9/site-packages (2.0.3)
# Requirement already satisfied: scikit-learn in ./.env/lib/python3.9/site-packages (1.3.2)
# Requirement already satisfied: statsmodels in ./.env/lib/python3.9/site-packages (0.14.1)
# Requirement already satisfied: mlflow in ./.env/lib/python3.9/site-packages (2.9.2)
# Requirement already satisfied: pytz>=2020.1 in ./.env/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./.env/lib/python3.9/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.env/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.env/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: frozendict>=2.3.4 in ./.env/lib/python3.9/site-packages (from yfinance) (2.3.10)
# Requirement already satisfied: html5lib>=1.1 in ./.env/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in ./.env/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./.env/lib/python3.9/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: peewee>=3.16.2 in ./.env/lib/python3.9/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: appdirs>=1.4.4 in ./.env/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.31 in ./.env/lib/python3.9/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: lxml>=4.9.1 in ./.env/lib/python3.9/site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: cycler>=0.10 in ./.env/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in ./.env/lib/python3.9/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.env/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.env/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.env/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.env/lib/python3.9/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.env/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.9/site-packages (from jinja2) (2.1.3)
# Requirement already satisfied: et-xmlfile in ./.env/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: scipy in ./.env/lib/python3.9/site-packages (from xgboost) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.env/lib/python3.9/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in ./.env/lib/python3.9/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: patsy>=0.5.4 in ./.env/lib/python3.9/site-packages (from statsmodels) (0.5.5)
# Requirement already satisfied: Flask<4 in ./.env/lib/python3.9/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: docker<7,>=4.0.0 in ./.env/lib/python3.9/site-packages (from mlflow) (6.1.3)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in ./.env/lib/python3.9/site-packages (from mlflow) (0.18.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./.env/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in ./.env/lib/python3.9/site-packages (from mlflow) (7.0.1)
# Requirement already satisfied: entrypoints<1 in ./.env/lib/python3.9/site-packages (from mlflow) (0.4)
# Requirement already satisfied: click<9,>=7.0 in ./.env/lib/python3.9/site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in ./.env/lib/python3.9/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: querystring-parser<2 in ./.env/lib/python3.9/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: protobuf<5,>=3.12.0 in ./.env/lib/python3.9/site-packages (from mlflow) (4.25.1)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in ./.env/lib/python3.9/site-packages (from mlflow) (14.0.2)
# Requirement already satisfied: gunicorn<22 in ./.env/lib/python3.9/site-packages (from mlflow) (21.2.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./.env/lib/python3.9/site-packages (from mlflow) (2.0.24)
# Requirement already satisfied: markdown<4,>=3.3 in ./.env/lib/python3.9/site-packages (from mlflow) (3.5.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in ./.env/lib/python3.9/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.env/lib/python3.9/site-packages (from mlflow) (0.4.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in ./.env/lib/python3.9/site-packages (from mlflow) (3.1.40)
# Requirement already satisfied: Mako in ./.env/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in ./.env/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (4.9.0)
# Requirement already satisfied: soupsieve>1.2 in ./.env/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: oauthlib>=3.1.0 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.9.0)
# Requirement already satisfied: pyjwt>=1.7.0 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.8.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.1.0)
# Requirement already satisfied: six>=1.10.0 in ./.env/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in ./.env/lib/python3.9/site-packages (from docker<7,>=4.0.0->mlflow) (1.7.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in ./.env/lib/python3.9/site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in ./.env/lib/python3.9/site-packages (from Flask<4->mlflow) (3.0.1)
# Requirement already satisfied: blinker>=1.6.2 in ./.env/lib/python3.9/site-packages (from Flask<4->mlflow) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.env/lib/python3.9/site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.env/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.1)
# Requirement already satisfied: webencodings in ./.env/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in ./.env/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2023.11.17)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/anshumankaran/Documents/GitHub/INFO7374_Predict_StockPrice/.env/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# Importing libraries.

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import yfinance as yf
import ta
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader._utils import RemoteDataError
# Out:
# /Users/anshumankaran/Documents/GitHub/INFO7374_Predict_StockPrice/.env/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# Define Start and End date for the data scope

# %%
# Start date
start_date = datetime(2023, 1, 1)
# End date
end_date = datetime(2023, 12, 31)

# %% [markdown]
# Download stock data for the 5 companies

# %%
# Our stock - NVDA
NVDA = yf.download("NVDA", start_date, end_date)

# Competitor stocks
# AMD
AMD = yf.download("AMD", start_date, end_date)
# Taiwan Semiconductor Mfg. Co
TSM = yf.download("TSM", start_date, end_date)
# Qualcomm
QCOM = yf.download("QCOM", start_date, end_date)
# Broadcom
AVGO = yf.download("AVGO", start_date, end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# Reading column names:

# %%
cols = list(NVDA.columns)
cols
# Out:
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %% [markdown]
# Subsetting the dataset for the featues we need:

# %%
NVDA_new = NVDA[["Open", "Close", "Adj Close", "Volume"]]
AMD_new = AMD[["Open", "Close", "Adj Close", "Volume"]]
TSM_new = TSM[["Open", "Close", "Adj Close", "Volume"]]
QCOM_new = QCOM[["Open", "Close", "Adj Close", "Volume"]]
AVGO_new = AVGO[["Open", "Close", "Adj Close", "Volume"]]

# %% [markdown]
# We define the *training period* from `01/01/2022 to 12/31/2022`.

# %%
# Training period - 2022
train_start_date = datetime(2022, 6, 1)
train_end_date = datetime(2023, 5, 31)
# Testing period - 2023
test_start_date = datetime(2023, 6, 1)
test_end_date = datetime(2023, 11, 30)

# %% [markdown]
# Renaming the features corresponding to each stock:

# %%
cols = list(NVDA_new.columns)
for col in cols:
    NVDA_new.rename(columns={col: "NVDA_" + col}, inplace=True)
    AMD_new.rename(columns={col: "AMD_" + col}, inplace=True)
    TSM_new.rename(columns={col: "TSM_" + col}, inplace=True)
    QCOM_new.rename(columns={col: "QCOM_" + col}, inplace=True)
    AVGO_new.rename(columns={col: "AVGO_" + col}, inplace=True)
# Out:
# /var/folders/73/z3xw9gmn0yv1ytg8yv66975w0000gn/T/ipykernel_26750/1823967568.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NVDA_new.rename(columns={col: "NVDA_" + col}, inplace=True)
# /var/folders/73/z3xw9gmn0yv1ytg8yv66975w0000gn/T/ipykernel_26750/1823967568.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AMD_new.rename(columns={col: "AMD_" + col}, inplace=True)
# /var/folders/73/z3xw9gmn0yv1ytg8yv66975w0000gn/T/ipykernel_26750/1823967568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TSM_new.rename(columns={col: "TSM_" + col}, inplace=True)
# /var/folders/73/z3xw9gmn0yv1ytg8yv66975w0000gn/T/ipykernel_26750/1823967568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QCOM_new.rename(columns={col: "QCOM_" + col}, inplace=True)
# /var/folders/73/z3xw9gmn0yv1ytg8yv66975w0000gn/T/ipykernel_26750/1823967568.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AVGO_new.rename(columns={col: "AVGO_" + col}, inplace=True)

# %% [markdown]
# Limiting the dataset for just the training period:

# %%
NVDA_new = NVDA_new.loc[train_start_date:train_end_date]
AMD_new = AMD_new.loc[train_start_date:train_end_date]
TSM_new = TSM_new.loc[train_start_date:train_end_date]
QCOM_new = QCOM_new.loc[train_start_date:train_end_date]
AVGO_new = AVGO_new.loc[train_start_date:train_end_date]

# %% [markdown]
# Concatinating the dataframes for NVDA and all the competitors:

# %%
final_df = pd.concat([NVDA_new, AMD_new, TSM_new, QCOM_new, AVGO_new], axis=1)
final_df
# Out:
#              NVDA_Open  NVDA_Close  NVDA_Adj Close  NVDA_Volume    AMD_Open  \
# Date
# 2023-01-03  148.509995  143.149994      143.086487     40127700   66.000000
# 2023-01-04  145.669998  147.490005      147.424591     43132400   65.000000
# 2023-01-05  144.910004  142.649994      142.586731     38916800   64.150002
# 2023-01-06  144.740005  148.589996      148.524094     40504400   63.150002
# 2023-01-09  152.839996  156.279999      156.210693     50423100   66.220001
# ...                ...         ...             ...          ...         ...
# 2023-05-24  302.100006  305.380005      305.296417     72141900  105.980003
# 2023-05-25  385.230011  379.799988      379.696014    154391100  117.309998
# 2023-05-26  378.899994  389.459991      389.353363     71439700  122.459999
# 2023-05-30  405.950012  401.109985      401.000214     92340100  130.419998
# 2023-05-31  394.880005  378.339996      378.236420    100258000  122.419998
#
#              AMD_Close  AMD_Adj Close  AMD_Volume    TSM_Open   TSM_Close  \
# Date
# 2023-01-03   64.019997      64.019997    46851800   75.849998   74.029999
# 2023-01-04   64.660004      64.660004    47477100   74.989998   76.320000
# 2023-01-05   62.330002      62.330002    46159500   76.000000   75.730003
# 2023-01-06   63.959999      63.959999    70161300   76.500000   78.070000
# 2023-01-09   67.239998      67.239998    69741300   80.559998   80.309998
# ...                ...            ...         ...         ...         ...
# 2023-05-24  108.269997     108.269997    65910500   89.279999   90.129997
# 2023-05-25  120.349998     120.349998   108514700   97.059998  100.949997
# 2023-05-26  127.029999     127.029999    92922800  100.849998  103.209999
# 2023-05-30  125.269997     125.269997    98902300  103.790001  101.980003
# 2023-05-31  118.209999     118.209999    87552200   99.730003   98.589996
#
#             TSM_Adj Close  TSM_Volume   QCOM_Open  QCOM_Close  QCOM_Adj Close  \
# Date
# 2023-01-03      72.618538     9276200  111.349998  107.199997      104.406326
# 2023-01-04      74.864876    12316400  109.800003  111.529999      108.623489
# 2023-01-05      74.286125    10039200  109.930000  109.400002      106.548996
# 2023-01-06      76.581512    13744100  110.959999  115.339996      112.334198
# 2023-01-09      78.778801    22247600  116.730003  114.610001      111.623222
# ...                   ...         ...         ...         ...             ...
# 2023-05-24      88.871811     9443900  102.080002  103.019997      100.948158
# 2023-05-25      99.540771    60793200  101.930000  104.019997      101.928047
# 2023-05-26     101.769226    26135800  104.940002  110.349998      108.130737
# 2023-05-30     100.556404    25248000  114.500000  116.000000      113.667114
# 2023-05-31      97.213715    22206700  113.559998  113.410004      111.900932
#
#             QCOM_Volume   AVGO_Open  AVGO_Close  AVGO_Adj Close  AVGO_Volume
# Date
# 2023-01-03      8110400  565.000000  553.479980      541.163330      2017300
# 2023-01-04      7614200  562.989990  560.239990      547.772949      1707400
# 2023-01-05      7546000  555.710022  555.020020      542.669067      1627700
# 2023-01-06     10259300  563.119995  588.429993      575.335571      3526100
# 2023-01-09     10291800  592.299988  576.890015      564.052429      3773900
# ...                 ...         ...         ...             ...          ...
# 2023-05-24      8193700  681.440002  679.530029      669.190552      2302100
# 2023-05-25     11677400  699.409973  728.799988      717.710754      4926300
# 2023-05-26     15969900  747.429993  812.729980      800.363708      8250000
# 2023-05-30     18291800  835.119995  803.340027      791.116638     11691200
# 2023-05-31     14924000  794.900024  807.960022      795.666321      8999800
#
# [103 rows x 20 columns]

# %% [markdown]
# ## Understanding the data

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 103 entries, 2023-01-03 to 2023-05-31
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NVDA_Open       103 non-null    float64
#  1   NVDA_Close      103 non-null    float64
#  2   NVDA_Adj Close  103 non-null    float64
#  3   NVDA_Volume     103 non-null    int64
#  4   AMD_Open        103 non-null    float64
#  5   AMD_Close       103 non-null    float64
#  6   AMD_Adj Close   103 non-null    float64
#  7   AMD_Volume      103 non-null    int64
#  8   TSM_Open        103 non-null    float64
#  9   TSM_Close       103 non-null    float64
#  10  TSM_Adj Close   103 non-null    float64
#  11  TSM_Volume      103 non-null    int64
#  12  QCOM_Open       103 non-null    float64
#  13  QCOM_Close      103 non-null    float64
#  14  QCOM_Adj Close  103 non-null    float64
#  15  QCOM_Volume     103 non-null    int64
#  16  AVGO_Open       103 non-null    float64
#  17  AVGO_Close      103 non-null    float64
#  18  AVGO_Adj Close  103 non-null    float64
#  19  AVGO_Volume     103 non-null    int64
# dtypes: float64(15), int64(5)
# memory usage: 16.9 KB

# %% [markdown]
# ## Summary Statistics

# %%
NVDA_new.columns
# Out:
# Index(['NVDA_Open', 'NVDA_Close', 'NVDA_Adj Close', 'NVDA_Volume'], dtype='object')

# %%
# Report view
report = final_df.describe().T  # Transpose index and columns
# Put report in a dataframe
report_df = pd.DataFrame(
    index=[
        "NVDA_Open",
        "NVDA_Close",
        "NVDA_Adj Close",
        "NVDA_Volume",
        "AMD_Open",
        "AMD_Close",
        "AMD_Adj Close",
        "AMD_Volume",
        "TSM_Open",
        "TSM_Close",
        "TSM_Adj Close",
        "TSM_Volume",
        "QCOM_Open",
        "QCOM_Close",
        "QCOM_Adj Close",
        "QCOM_Volume",
        "AVGO_Open",
        "AVGO_Close",
        "AVGO_Adj Close",
        "AVGO_Volume"
    ],
    columns=["count", "mean", "std", "min", "25%", "50%", "75%", "max"],
    data=report,
)
# Plot the report
f, ax = plt.subplots(figsize=(12, 10))
# Heatmap
sns.heatmap(report_df, annot=True, cmap="Blues", fmt=".0f")
plt.xticks(size=12)
plt.yticks(size=12, rotation=0)
plt.ylabel("Variables")
plt.title("Descriptive Statistics", size=16)
plt.show()

# %% [markdown]
# ## Kernel Density Plots

# %%
final_cols = final_df.columns

# %%
# Plotting 'price' target variable
fig, ax = plt.subplots(20, 1, figsize=(10, 40))
for i, col in enumerate(final_cols):
    sns.histplot(final_df[col], kde=True, bins="auto", ax=ax[i])
    ax[i].set_xlabel(col)
fig.suptitle("Kernel Density Plots", fontsize=16)
fig.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %% [markdown]
# ## Plotting Adj_Close price for all companies

# %%
import matplotlib.pyplot as plt

company_list = ["NVDA", "AMD", "TSM", "QCOM", "AVGO"]
plt.figure(figsize=(12, 8))

for company in company_list:
    plt.plot(final_df[company + "_Close"], label=company)

plt.ylabel("Adj Close")
plt.xlabel("Date")
plt.title("Stock Closing Prices")
plt.legend()
plt.show()

# %% [markdown]
# ## Plotting Volume of stocks sold for all companies

# %%
plt.figure(figsize=(12, 8))
plt.subplots_adjust(top=1.25, bottom=1.2)
plt.title("Total Volume of Stock Traded Each Day")

for company in company_list:
    final_df[company + "_Volume"].plot(label=company)

plt.ylabel("Volume")
plt.xlabel("Date")
plt.legend()
plt.show()

# %% [markdown]
# #### Pairplot to analyze relationship between Close price of all five company stocks

# %%
# Making a new DataFrame for returns
tech_rets = final_df[
    ["NVDA_Close", "AMD_Close", "TSM_Close", "QCOM_Close", "AVGO_Close"]
].pct_change()
sns.pairplot(tech_rets, kind="reg")

# %% [markdown]
# ## Correlation between Open prices of all five stocks

# %%
final_df[
    ["NVDA_Open", "AMD_Open", "TSM_Open", "QCOM_Open", "AVGO_Open"]
].corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_a6cd6_row0_col0, #T_a6cd6_row1_col1, #T_a6cd6_row2_col2, #T_a6cd6_row3_col3, #T_a6cd6_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a6cd6_row0_col1 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_a6cd6_row0_col2, #T_a6cd6_row0_col3, #T_a6cd6_row3_col0, #T_a6cd6_row3_col1, #T_a6cd6_row3_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a6cd6_row0_col4 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_a6cd6_row1_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_a6cd6_row1_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_a6cd6_row1_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a6cd6_row1_col4, #T_a6cd6_row4_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_a6cd6_row2_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_a6cd6_row2_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_a6cd6_row2_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a6cd6_row2_col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_a6cd6_row3_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a6cd6_row4_col0 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_a6cd6_row4_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a6cd6_row4_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a6cd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6cd6_level0_col0" class="col_heading level0 col0" >NVDA_Open</th>
#       <th id="T_a6cd6_level0_col1" class="col_heading level0 col1" >AMD_Open</th>
#       <th id="T_a6cd6_level0_col2" class="col_heading level0 col2" >TSM_Open</th>
#       <th id="T_a6cd6_level0_col3" class="col_heading level0 col3" >QCOM_Open</th>
#       <th id="T_a6cd6_level0_col4" class="col_heading level0 col4" >AVGO_Open</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6cd6_level0_row0" class="row_heading level0 row0" >NVDA_Open</th>
#       <td id="T_a6cd6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a6cd6_row0_col1" class="data row0 col1" >0.946313</td>
#       <td id="T_a6cd6_row0_col2" class="data row0 col2" >0.368737</td>
#       <td id="T_a6cd6_row0_col3" class="data row0 col3" >-0.438811</td>
#       <td id="T_a6cd6_row0_col4" class="data row0 col4" >0.890048</td>
#     </tr>
#     <tr>
#       <th id="T_a6cd6_level0_row1" class="row_heading level0 row1" >AMD_Open</th>
#       <td id="T_a6cd6_row1_col0" class="data row1 col0" >0.946313</td>
#       <td id="T_a6cd6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a6cd6_row1_col2" class="data row1 col2" >0.495352</td>
#       <td id="T_a6cd6_row1_col3" class="data row1 col3" >-0.350920</td>
#       <td id="T_a6cd6_row1_col4" class="data row1 col4" >0.916553</td>
#     </tr>
#     <tr>
#       <th id="T_a6cd6_level0_row2" class="row_heading level0 row2" >TSM_Open</th>
#       <td id="T_a6cd6_row2_col0" class="data row2 col0" >0.368737</td>
#       <td id="T_a6cd6_row2_col1" class="data row2 col1" >0.495352</td>
#       <td id="T_a6cd6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a6cd6_row2_col3" class="data row2 col3" >0.451849</td>
#       <td id="T_a6cd6_row2_col4" class="data row2 col4" >0.474251</td>
#     </tr>
#     <tr>
#       <th id="T_a6cd6_level0_row3" class="row_heading level0 row3" >QCOM_Open</th>
#       <td id="T_a6cd6_row3_col0" class="data row3 col0" >-0.438811</td>
#       <td id="T_a6cd6_row3_col1" class="data row3 col1" >-0.350920</td>
#       <td id="T_a6cd6_row3_col2" class="data row3 col2" >0.451849</td>
#       <td id="T_a6cd6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a6cd6_row3_col4" class="data row3 col4" >-0.388488</td>
#     </tr>
#     <tr>
#       <th id="T_a6cd6_level0_row4" class="row_heading level0 row4" >AVGO_Open</th>
#       <td id="T_a6cd6_row4_col0" class="data row4 col0" >0.890048</td>
#       <td id="T_a6cd6_row4_col1" class="data row4 col1" >0.916553</td>
#       <td id="T_a6cd6_row4_col2" class="data row4 col2" >0.474251</td>
#       <td id="T_a6cd6_row4_col3" class="data row4 col3" >-0.388488</td>
#       <td id="T_a6cd6_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Expected Return vs. Risk

# %%
rets = tech_rets.dropna()
area = np.pi * 20
plt.figure(figsize=(12, 10))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel("Expected return")
plt.ylabel("Risk")
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(50, 50),
        textcoords="offset points",
        ha="right",
        va="bottom",
        arrowprops=dict(arrowstyle="-", color="blue", connectionstyle="arc3,rad=-0.3"),
    )

# %% [markdown]
# ## Plotting Stock Trend and Pct. Returns

# %%
def plot_stock_trend_and_returns(ticker, titles, start_date, end_date, all_returns):
    # Get the data for this ticker
    prices = yf.download(ticker, start_date, end_date)
    prices = prices.Close

    # prices = web.DataReader(ticker, 'yahoo', start=start_date, end=end_date).Close
    prices.index = [d.date() for d in prices.index]

    plt.figure(figsize=(10, 6))

    # Plot stock price
    plt.subplot(2, 1, 1)
    plt.plot(prices)
    plt.title(titles[0], fontsize=16)
    plt.ylabel("Price ($)", fontsize=14)

    # Plot stock returns
    plt.subplot(2, 1, 2)
    plt.plot(all_returns[0], all_returns[1], color="g")
    plt.title(titles[1], fontsize=16)
    plt.ylabel("Pct. Return", fontsize=14)
    plt.axhline(0, color="k", linestyle="--")

    plt.tight_layout()

    plt.show()

# %% [markdown]
# ## Stock Performance Analysis

# %%
def perform_analysis_for_stock(
    ticker, start_date, end_date, return_period_weeks, verbose=False
):
    """
    Inputs:
        ticker: the ticker symbol to analyze
        start_date: the first date considered in simulation
        end_date: the last date considered in simulation
        return_period_weeks: the number of weeks in which to calculate returns
        verbose: True if you want to print simulation steps

    Outputs:
        average and standard deviation of returns for simulated runs of this ticker within the given date range
    """

    # Get the data for this ticker
    try:
        prices = yf.download(ticker, start_date, end_date)
        prices = prices.Close
    # Could not find data on this ticker
    except (RemoteDataError, KeyError):
        # Return default values
        return -np.inf, np.inf, None

    prices.index = [d.date() for d in prices.index]

    # This will store all simulated returns
    pct_return_after_period = []
    buy_dates = []

    # Assume we buy the stock on each day in the range
    for buy_date, buy_price in prices.items():
        # Get price of the stock after given number of weeks
        sell_date = buy_date + timedelta(weeks=return_period_weeks)

        try:
            sell_price = prices[prices.index == sell_date].iloc[0]
        # Trying to sell on a non-trading day, skip
        except IndexError:
            continue

        # Compute the percent return
        pct_return = (sell_price - buy_price) / buy_price
        pct_return_after_period.append(pct_return)
        buy_dates.append(buy_date)

        if verbose:
            print("Date Buy: %s, Price Buy: %s" % (buy_date, round(buy_price, 2)))
            print("Date Sell: %s, Price Sell: %s" % (sell_date, round(sell_price, 2)))
            print("Return: %s%%" % round(pct_return * 100, 1))
            print("-------------------")

    # If no data collected return default values
    if len(pct_return_after_period) == 0:
        return -np.inf, np.inf, None

    # Report average and deviation of the percent returns
    return (
        np.mean(pct_return_after_period),
        np.std(pct_return_after_period),
        [buy_dates, pct_return_after_period],
    )

# %%
# Start date for simulation.
# Further back means more training data but risk of including patterns that no longer exist
# More recent means less training data but only using recent patterns
start_date, end_date = datetime(2023, 6, 1), datetime(2023, 12, 1)

# set number of weeks in which you want to see return
return_period_weeks = 4

# Minimum average return
min_avg_return = 0.1

# Maximum volatility in return
max_dev_return = 0.07

# %%
stocks = ["AMD", "TSM", "QCOM", "NVDA", "AVGO"]
for stock in stocks:
    avg_return, dev_return, all_returns = perform_analysis_for_stock(
        stock, start_date, end_date, return_period_weeks
    )
    title_price = "%s\n%s" % (stock, "Common Stock")
    title_return = "Avg Return: %s%% | Dev Return: %s%%" % (
        round(100 * avg_return, 2),
        round(100 * dev_return, 2),
    )
    plot_stock_trend_and_returns(
        stock, [title_price, title_return], start_date, end_date, all_returns
    )
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
